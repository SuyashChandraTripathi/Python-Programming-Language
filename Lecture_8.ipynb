# %% [markdown]
# <a href="https://colab.research.google.com/github/SuyashChandraTripathi/Python-Programming-Language/blob/main/Lecture_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WHILE LOOP QUES. PRACTICE

# %%
#Keep asking for a password until the correct one is entered (Correct Password = "Password@321").
p =" "
password = "Password@321"
while p != password:
  p = input ()
print("Correct password entered !!")
# Out:
# Password@321
# Correct password entered

# %% [markdown]
# #Break and Continue

# %%
for i in range (1,10):
  print(i)

  if i == 5:
    break
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#Keep asking for a password until the correct one is entered
password = "Pass@321"
while True:
  a = input()

  if a == password:
    break
print("Correct Pass entered")
# Out:
# dhufkf
# dijdkl
# Pass@321
# Correct Pass entered

# %%
for i in range (1,11,2):
   if i == 6:
    break

   print (i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range (0,11,2):
  if i == 6:
    break

  print (i)
# Out:
# 0
# 2
# 4

# %%
for i in range (1,10):

  if i == 5:
    break

  print (i)
# Out:
# 1
# 2
# 3
# 4

# %%
#Print all the even numbers between 1 to 10 (both inclusive) using continue statement

for i in range (1,11,1):

  if (i % 2 != 0):
    continue
  print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
#Infinite Loop
i = 1
while i <= 5:
  if i == 3:
    break
  print (i)

  i += 1
# Out:
# 1
# 2
